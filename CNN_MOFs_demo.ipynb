# %% [markdown]
# <a href="https://colab.research.google.com/github/ChrizZhuang/DS_project_MOF_H2_ML/blob/main/CNN_MOFs_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !ls
# Out:
# 820k_mofs_crytal_props_ml_h2_ps_v17feb2021.csv	820k_utf-8.csv	sample_data

# %%
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
import tensorflow_datasets as tfds
import pandas as pd
import csv

# %% [markdown]
# # Load the data

# %% [markdown]
# ### Turn the csv into utf-8 for pd.read_csv

# %%
path =  '820k_mofs_crytal_props_ml_h2_ps_v17feb2021.csv'

with open(path, 'r', encoding='utf-8', errors='ignore') as infile, open('820k_utf-8.csv', 'w') as outfile:
     inputs = csv.reader(infile)
     output = csv.writer(outfile)

     for index, row in enumerate(inputs):
       output.writerow(row)
# https://stackoverflow.com/questions/32403209/convert-csv-to-utf-8-in-python

# %%
data = pd.read_csv('820k_utf-8.csv')
data
# Out:
#                                     Name  ...                   Crystal Structure Availability
# 0                  Al2O6-ADC_B-AZO_B_No1  ...                                      Open Source
# 1                 Al2O6-ADC_B-AZO_B_No10  ...                                      Open Source
# 2                Al2O6-ADC_B-AZO_B_No100  ...                                      Open Source
# 3                Al2O6-ADC_B-AZO_B_No101  ...                                      Open Source
# 4                Al2O6-ADC_B-AZO_B_No102  ...                                      Open Source
# ...                                  ...  ...                                              ...
# 820034  str_m9_o2_o22_f0_sra.sym.227.out  ...  https://archive.materialscloud.org/2018.0016/v2
# 820035  str_m3_o24_o24_f0_pcu.sym.10.out  ...  https://archive.materialscloud.org/2018.0016/v2
# 820036                 NU-TPE-4PTT-csq-l  ...                                      Open Source
# ...

# %%
def feature_extractor(inputs):
  
  return feature_extractor
